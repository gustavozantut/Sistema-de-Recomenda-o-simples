# %%
# https://udemy.com/recommender-systems
# https://deeplearningcourses.com/recommender-systems
from __future__ import print_function, division
from builtins import range, input

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from scipy.sparse import lil_matrix, csr_matrix, save_npz, load_npz

# load in the data
df = pd.read_csv('large_files/movielens-20m-dataset/edited_rating.csv')

N = df.userId.max() + 1 # number of users
M = df.movie_idx.max() + 1 # number of movies

# split into train and test
df = shuffle(df)
cutoff = int(0.8*len(df))
df_train = df.iloc[:cutoff]
df_test = df.iloc[cutoff:]

# %%
#criando uma matrix esparsa (matriz contendo ruidos para utilizar o autorec)  

#criando matriz de notas

#matriz de treino
A = lil_matrix((N, M))#setando a matriz esparsa
print("Calling: update_train")
count = 0
def update_train(row):#funcao para preencher matriz esparsa
  global count
  count += 1
  if count % 100000 == 0:
    print("processed: %.3f" % (float(count)/cutoff))

  i = int(row.userId)
  j = int(row.movie_idx)
  A[i,j] = row.rating
df_train.apply(update_train, axis=1)
# Out:
# Calling: update_train
# processed: 0.006
# processed: 0.012
# processed: 0.019
# processed: 0.025
# processed: 0.031
# processed: 0.037
# processed: 0.044
# processed: 0.050
# processed: 0.056
# processed: 0.062
# processed: 0.069
# processed: 0.075
# processed: 0.081
# processed: 0.087
# processed: 0.094
# processed: 0.100
# processed: 0.106
# processed: 0.112
# processed: 0.119
# processed: 0.125
# processed: 0.131
# processed: 0.137
# processed: 0.144
# processed: 0.150
# processed: 0.156
# processed: 0.162
# processed: 0.169
# processed: 0.175
# processed: 0.181
# processed: 0.187
# processed: 0.194
# processed: 0.200
# processed: 0.206
# processed: 0.212
# processed: 0.219
# processed: 0.225
# processed: 0.231
# processed: 0.237
# processed: 0.244
# processed: 0.250
# processed: 0.256
# processed: 0.262
# processed: 0.269
# processed: 0.275
# processed: 0.281
# processed: 0.287
# processed: 0.294
# processed: 0.300
# processed: 0.306
# processed: 0.312
# processed: 0.319
# processed: 0.325
# processed: 0.331
# processed: 0.337
# processed: 0.344
# processed: 0.350
# processed: 0.356
# processed: 0.362
# processed: 0.369
# processed: 0.375
# processed: 0.381
# processed: 0.387
# processed: 0.394
# processed: 0.400
# processed: 0.406
# processed: 0.412
# processed: 0.419
# processed: 0.425
# processed: 0.431
# processed: 0.437
# processed: 0.444
# processed: 0.450
# processed: 0.456
# processed: 0.462
# processed: 0.469
# processed: 0.475
# processed: 0.481
# processed: 0.487
# processed: 0.494
# processed: 0.500
# processed: 0.506
# processed: 0.512
# processed: 0.519
# processed: 0.525
# processed: 0.531
# processed: 0.537
# processed: 0.544
# processed: 0.550
# processed: 0.556
# processed: 0.562
# processed: 0.569
# processed: 0.575
# processed: 0.581
# processed: 0.587
# processed: 0.594
# processed: 0.600
# processed: 0.606
# processed: 0.612
# processed: 0.619
# processed: 0.625
# processed: 0.631
# processed: 0.637
# processed: 0.644
# processed: 0.650
# processed: 0.656
# processed: 0.662
# processed: 0.669
# processed: 0.675
# processed: 0.681
# processed: 0.687
# processed: 0.694
# processed: 0.700
# processed: 0.706
# processed: 0.712
# processed: 0.719
# processed: 0.725
# processed: 0.731
# processed: 0.737
# processed: 0.744
# processed: 0.750
# processed: 0.756
# processed: 0.762
# processed: 0.769
# processed: 0.775
# processed: 0.781
# processed: 0.787
# processed: 0.794
# processed: 0.800
# processed: 0.806
# processed: 0.812
# processed: 0.819
# processed: 0.825
# processed: 0.831
# processed: 0.837
# processed: 0.844
# processed: 0.850
# processed: 0.856
# processed: 0.862
# processed: 0.869
# processed: 0.875
# processed: 0.881
# processed: 0.887
# processed: 0.894
# processed: 0.900
# processed: 0.906
# processed: 0.912
# processed: 0.919
# processed: 0.925
# processed: 0.931
# processed: 0.937
# processed: 0.944
# processed: 0.950
# processed: 0.956
# processed: 0.962
# processed: 0.969
# processed: 0.975
# processed: 0.981
# processed: 0.987
# processed: 0.994
# processed: 1.000
# 12368099    None
# 593745      None
# 12618831    None
# 6185732     None
# 11036640    None
#             ...
# 16405907    None
# 17952967    None
# 16938468    None
# 9872904     None
# 6515528     None
# Length: 16000210, dtype: object

# %%
# mascara para sabermos quais dados existem e quais são ruidos
A = A.tocsr()
mask = (A > 0)
save_npz("Atrain.npz", A)

# %%
#martriz de teste
A_test = lil_matrix((N, M))
print("Calling: update_test")
count = 0
def update_test(row):
  global count
  count += 1
  if count % 100000 == 0:
    print("processed: %.3f" % (float(count)/len(df_test)))

  i = int(row.userId)
  j = int(row.movie_idx)
  A_test[i,j] = row.rating
# Out:
# Calling: update_test

# %%
df_test.apply(update_test, axis=1)
A_test = A_test.tocsr()
mask_test = (A_test > 0)
save_npz("Atest.npz", A_test)
# Out:
# processed: 0.025
# processed: 0.050
# processed: 0.075
# processed: 0.100
# processed: 0.125
# processed: 0.150
# processed: 0.175
# processed: 0.200
# processed: 0.225
# processed: 0.250
# processed: 0.275
# processed: 0.300
# processed: 0.325
# processed: 0.350
# processed: 0.375
# processed: 0.400
# processed: 0.425
# processed: 0.450
# processed: 0.475
# processed: 0.500
# processed: 0.525
# processed: 0.550
# processed: 0.575
# processed: 0.600
# processed: 0.625
# processed: 0.650
# processed: 0.675
# processed: 0.700
# processed: 0.725
# processed: 0.750
# processed: 0.775
# processed: 0.800
# processed: 0.825
# processed: 0.850
# processed: 0.875
# processed: 0.900
# processed: 0.925
# processed: 0.950
# processed: 0.975
# processed: 1.000
